# %% [markdown]
# # Analiza wyników symulacji systemu wind
#
# Ten notebook służy do analizy i eksperymentowania z różnymi parametrami symulacji.

# %%
import sys
sys.path.append('..')

from src import run_simulation, plot_results
import matplotlib.pyplot as plt

# %% [markdown]
# ## Uruchomienie symulacji z różnymi parametrami

# %%
# Przykładowa symulacja
sim_time = 500
resA = run_simulation('A', sim_time, seed=42)
resB = run_simulation('B', sim_time, seed=42)
# Out:
# === Start symulacji: A, czas: 500 ===
# WYNIKI:
# Średni czas oczekiwania: 43.86
# Średni czas przejazdu: 8.18
# Łącznie obsłużonych pasażerów: 256
# Łączny czas ruchu wind: 1106.00
#
# === Start symulacji: B, czas: 500 ===
# WYNIKI:
# Średni czas oczekiwania: 52.91
# Średni czas przejazdu: 8.80
# Łącznie obsłużonych pasażerów: 263
# Łączny czas ruchu wind: 1220.00

# %%
# Wizualizacja wyników
plot_results(resA, resB, sim_time)
